# %% [markdown]
# # **Homework 5 (Colab Version)**

# %%
# %pip install -U PySuperTuxKart
# Out:
# Requirement already satisfied: PySuperTuxKart in /usr/local/lib/python3.7/dist-packages (1.1.2)
# Requirement already satisfied: PySuperTuxKartData in /usr/local/lib/python3.7/dist-packages (from PySuperTuxKart) (1.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from PySuperTuxKartData->PySuperTuxKart) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->PySuperTuxKartData->PySuperTuxKart) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->PySuperTuxKartData->PySuperTuxKart) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->PySuperTuxKartData->PySuperTuxKart) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->PySuperTuxKartData->PySuperTuxKart) (3.0.4)

# %% [markdown]
# ## **Generating the Dataset**
#
# All the cells in the section go towards generating the dataset.
#
# Skip to the next section "Training the Model" if you already have `drive_data.zip`.

# %% [markdown]
# ### **Import Files From Google Drive**
#
# Upload homework5_colab to google drive </br>
# The path set to "/content/drive/MyDrive/homework5_colab/"

# %%
# import os

# os.environ['USER'] = 'alicebob'
# os.environ['PASS'] = '123123'
# os.environ['REPO'] = 'dl'

# !git clone https://$USER:$PASS@github.com/$USER/$REPO.git cs342
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ### **Navigate to your `homework5_colab` directory**
#
# You'll need to edit this.
#
# Make sure the `ls` shows that you have a `homework` and `grader` directory present.

# %%
# !git pull origin master
# %cd /content/drive/MyDrive/homework5_colab/
# !ls
# Out:
# /content/drive/MyDrive/homework5_colab
#  bundle.py	   grader    'Homework 5_files'
#  environment.yml   homework   requirements.txt

# %% [markdown]
# ### **Controller Tuning**
#
# Open up `homework/controller.py` from the file explorer in colab, and tweak your autoplot.
#
# Make sure to save a copy of the updated `controller.py` since the edits done in colab will be erased when the runtime closes.

# %%
# Environmental flag to visualize in colab.
# %env ON_COLAB=1

# Need to reload modules so the updated code gets run.
from importlib import reload
from homework import utils; reload(utils)
from homework import controller; reload(controller)

# Hack for notebooks.
if 'pytux' not in locals():
    pytux = utils.PyTux()

controller.test_controller(pytux, 'lighthouse', verbose=True)
# Out:
# env: ON_COLAB=1
# Finished at t=488
# 488 0.9980696551552388

# %% [markdown]
# ### **Collecting Data**

# %%
# Environmental flag to visualize in colab.
# %env ON_COLAB=1

# Need to reload modules so the updated code gets run.
from importlib import reload
from homework import controller; reload(controller)
from homework import utils; reload(utils)

# Hack for notebooks.
if 'pytux' not in locals():
    pytux = utils.PyTux()

# Modify any of the arguments below to tweak the generated dataset.
track = ['lighthouse']
verbose = True

# Dataset will be collected in a directory called "drive_data".
utils.main(pytux, track, n_images=10000, steps_per_track=20000, aim_noise=0.1, vel_noise=5, verbose=verbose)
# Out:
# env: ON_COLAB=1
# Finished at t=490
# 490 0.9996666102230236
# Finished at t=528
# 528 0.9985047406070067
# Finished at t=572
# 572 0.999035347848807
# Finished at t=543
# 543 0.9992228535847968
# Finished at t=620
# 620 0.9996147218432528
# Finished at t=593
# 593 1.0000436334102618
# Finished at t=547
# 547 0.9986669264785362
# Finished at t=621
# 621 0.9984391864373765
# Finished at t=581
# 581 0.9986932175158799
# Finished at t=629
# 629 0.9989324035231655
# Finished at t=581
# 581 0.9983084943150661
# Finished at t=616
# 616 0.9982527212437617
# Finished at t=570
# 570 1.000143872325728
# Finished at t=627
# 627 0.9996242948331036
# Finished at t=553
# 553 1.0002379373564354
# Finished at t=590
# 590 0.9993692925817167
# Finished at t=552
# 552 1.0002019345902577
# Finished at t=528
# 528 0.9995320334091796
# Finished at t=557
# 557 0.9987884618279458
# Finished at t=575
# 575 0.9994157007716454
# Finished at t=603
# 603 0.9980344154534694
# Finished at t=681
# 681 0.999208216622054
# Finished at t=575
# 575 0.99957892718555
# Finished at t=591
# 591 0.9997622013825478
# Finished at t=622
# 622 0.9983027366472573
# Finished at t=580
# 580 0.9983269465998509
# Finished at t=579
# 579 0.9986660246751444
# Finished at t=566
# 566 0.9984644369323451
# Finished at t=589
# 589 0.9995610298566986
# Finished at t=574
# 574 0.9993984277682191
# Finished at t=638
# 638 0.9994649531107327
# Finished at t=587
# 587 0.9988583862755513
# Finished at t=591
# 591 0.9997507554164219
# Finished at t=592
# 592 0.9987847852448871
# Finished at t=553
# 553 0.9986377219225422

# %% [markdown]
# ### **Download the Dataset**
#
# **OPTIONAL:** If you don't want to recollect data in the future, download the dataset to your machine.
#
# The data will disappear when the runtime disconnects!

# %%
# !zip -rq drive_data.zip drive_data
# !du -sh drive_data.zip

from google.colab import files

files.download('drive_data.zip')
# Out:
# 152M	drive_data.zip

# %% [markdown]
# ## **Training the Model**
#
# These cells will be very similar to the previous colab starter kit.

# %% [markdown]
# ### **Upload the Dataset**
#
# You'll need to run this cell if the runtime that generated the dataset disconnected.
#
# This might take a while depending on your internet connection, so it's up to you if you want to do this, or just regenerate your dataset.
#
# Make sure this is the zip file you downloaded from the cell above.

# %%
from google.colab import files

drive_data_zip = files.upload()
filename = tuple(drive_data_zip.keys())[0]

# !rm -rf drive_data
# !unzip $filename

# %% [markdown]
# ### **Tensorboard**

# %%
# %reload_ext tensorboard
# %tensorboard --logdir . --reload_interval 1

# %% [markdown]
# ### **Train the Network**

# %%
# !python3 -m homework.train

# %% [markdown]
# ### **Test the Planner**

# %%
# Environmental flag to visualize in colab.
# %env ON_COLAB=1

# Need to reload modules so the updated code gets run.
from importlib import reload
from homework import utils; reload(utils)
from homework import controller; reload(controller)
from homework import planner; reload(planner)

# Hack for notebooks.
if 'pytux' not in locals():
    pytux = utils.PyTux()

planner.test_planner(pytux, 'cocoa_temple', verbose=True)

# %% [markdown]
# ### **Grade and Download**

# %%
# !python3 -m grader homework -v
# !python3 bundle.py homework myeid1234

from google.colab import files; files.download('myeid1234.zip')
